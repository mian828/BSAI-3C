# %%
import pandas as pd

# %% [markdown]
#  # Fake Review System

# %%
df=pd.read_csv("fake reviews dataset.csv")

# %%
df.head(3)
# Out:
#              category  rating label  \
# 0  Home_and_Kitchen_5     5.0    CG
# 1  Home_and_Kitchen_5     5.0    CG
# 2  Home_and_Kitchen_5     5.0    CG
#
#                                                text_
# 0  Love this!  Well made, sturdy, and very comfor...
# 1  love it, a great upgrade from the original.  I...
# 2  This pillow saved my back. I love the look and...

# %%
df.columns
# Out:
# Index(['category', 'rating', 'label', 'text_'], dtype='object')

# %%
df.tail
# Out:
# <bound method NDFrame.tail of                            category  rating label  \
# 0                Home_and_Kitchen_5     5.0    CG
# 1                Home_and_Kitchen_5     5.0    CG
# 2                Home_and_Kitchen_5     5.0    CG
# 3                Home_and_Kitchen_5     1.0    CG
# 4                Home_and_Kitchen_5     5.0    CG
# ...                             ...     ...   ...
# 40427  Clothing_Shoes_and_Jewelry_5     4.0    OR
# 40428  Clothing_Shoes_and_Jewelry_5     5.0    CG
# 40429  Clothing_Shoes_and_Jewelry_5     2.0    OR
# 40430  Clothing_Shoes_and_Jewelry_5     1.0    CG
# 40431  Clothing_Shoes_and_Jewelry_5     5.0    OR
#
#                                                    text_
# 0      Love this!  Well made, sturdy, and very comfor...
# 1      love it, a great upgrade from the original.  I...
# 2      This pillow saved my back. I love the look and...
# 3      Missing information on how to use it, but it i...
# ...

# %%
df.count
# Out:
# <bound method DataFrame.count of                            category  rating label  \
# 0                Home_and_Kitchen_5     5.0    CG
# 1                Home_and_Kitchen_5     5.0    CG
# 2                Home_and_Kitchen_5     5.0    CG
# 3                Home_and_Kitchen_5     1.0    CG
# 4                Home_and_Kitchen_5     5.0    CG
# ...                             ...     ...   ...
# 40427  Clothing_Shoes_and_Jewelry_5     4.0    OR
# 40428  Clothing_Shoes_and_Jewelry_5     5.0    CG
# 40429  Clothing_Shoes_and_Jewelry_5     2.0    OR
# 40430  Clothing_Shoes_and_Jewelry_5     1.0    CG
# 40431  Clothing_Shoes_and_Jewelry_5     5.0    OR
#
#                                                    text_
# 0      Love this!  Well made, sturdy, and very comfor...
# 1      love it, a great upgrade from the original.  I...
# 2      This pillow saved my back. I love the look and...
# 3      Missing information on how to use it, but it i...
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                            category  rating label  \
# 0                Home_and_Kitchen_5     5.0    CG
# 1                Home_and_Kitchen_5     5.0    CG
# 2                Home_and_Kitchen_5     5.0    CG
# 3                Home_and_Kitchen_5     1.0    CG
# 4                Home_and_Kitchen_5     5.0    CG
# ...                             ...     ...   ...
# 40427  Clothing_Shoes_and_Jewelry_5     4.0    OR
# 40428  Clothing_Shoes_and_Jewelry_5     5.0    CG
# 40429  Clothing_Shoes_and_Jewelry_5     2.0    OR
# 40430  Clothing_Shoes_and_Jewelry_5     1.0    CG
# 40431  Clothing_Shoes_and_Jewelry_5     5.0    OR
#
#                                                    text_
# 0      Love this!  Well made, sturdy, and very comfor...
# 1      love it, a great upgrade from the original.  I...
# 2      This pillow saved my back. I love the look and...
# 3      Missing information on how to use it, but it i...
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                            category  rating label  \
# 0                Home_and_Kitchen_5     5.0    CG
# 1                Home_and_Kitchen_5     5.0    CG
# 2                Home_and_Kitchen_5     5.0    CG
# 3                Home_and_Kitchen_5     1.0    CG
# 4                Home_and_Kitchen_5     5.0    CG
# ...                             ...     ...   ...
# 40427  Clothing_Shoes_and_Jewelry_5     4.0    OR
# 40428  Clothing_Shoes_and_Jewelry_5     5.0    CG
# 40429  Clothing_Shoes_and_Jewelry_5     2.0    OR
# 40430  Clothing_Shoes_and_Jewelry_5     1.0    CG
# 40431  Clothing_Shoes_and_Jewelry_5     5.0    OR
#
#                                                    text_
# 0      Love this!  Well made, sturdy, and very comfor...
# 1      love it, a great upgrade from the original.  I...
# 2      This pillow saved my back. I love the look and...
# 3      Missing information on how to use it, but it i...
# ...

# %%
df.shape
print(f"Number of Rows: {df.shape[0]} and Number of Columns: {df.shape[1]}")
# Out:
# Number of Rows: 40432 and Number of Columns: 4

# %%
df.nunique()
# Out:
# category       10
# rating          5
# label           2
# text_       40412
# dtype: int64

# %%
df.isnull().any()
# Out:
# category    False
# rating      False
# label       False
# text_       False
# dtype: bool

# %%
df = df[df['text_'].str.split().str.len() > 4]

# %%
df['length'] = df['text_'].apply(len) #storing the length of all the text into a separate column called 'length'

# %%
df[df['label']=='OR'][['text_','length']].sort_values(by='length',ascending=False).head().iloc[0].text_ ##so here we are just collecting the words which are most common in the fake reviews so that we can identify these wrods to detect for future text
# Out:
# 'WEAK ON CURRENT SCIENCE.\nAfter seeing it twice, I agree with much (but not all) of the positive five star reviews. Out of respect for those who READ reviews, I\'ll not repeat everything that I like about the presentation. I found the goofy oversize earrings, hairdo, and facial hair arrangement of Daniel Vitalis, (described as a "Wild Food Expert") distracting. UGH. Ditto for David Wolfe, who had an extremely goofy wild hairdo. On the other hand, Jon Gabriel, described as an "author and weight loss expert" was nicely groomed and a good presenter. His story of personal transformation of a fellow of over 400 pounds (whew) to becoming a jock of normal weight was inspiring. Christiane Northrup preserves her rank as one of America\'s cutest doctors. A really nice looking woman! Presentations by Dr. Mercola, Jason Vale, Kris Carr, Alejandro Junger were fine. It was disappointing to have Jamie Oliver (so popular in the UK) give Baby Cow Growth Fluid a pass with unscientific but popular ide
# ...

# %%
import pandas as pd
import string
import pickle

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv("fake reviews dataset.csv")
print(df.shape)
print(df.columns)
# Out:
# (40432, 4)
# Index(['category', 'rating', 'label', 'text_'], dtype='object')

# %%
def clean_text(text):
    if not isinstance(text, str):
        return ""
    text = text.lower()
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = text.strip()
    return text

df['clean_text'] = df['text_'].apply(clean_text)

# %%
X = df['clean_text']
y = df['label']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

# %%
tfidf = TfidfVectorizer(max_features=20000, ngram_range=(1,2))
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
model = LogisticRegression(max_iter=1000, solver='liblinear')  # liblinear good for small-medium data
model.fit(X_train_tfidf, y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='liblinear')

# %%
y_pred = model.predict(X_test_tfidf)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9326276216857934
#
# Classification Report:
#                precision    recall  f1-score   support
#
#           CG       0.94      0.92      0.93      5054
#           OR       0.92      0.95      0.93      5054
#
#     accuracy                           0.93     10108
#    macro avg       0.93      0.93      0.93     10108
# weighted avg       0.93      0.93      0.93     10108

# %%
with open("fake_review_model.pkl", "wb") as f:
    pickle.dump(model, f)

with open("tfidf_vectorizer.pkl", "wb") as f:
    pickle.dump(tfidf, f)

print("file save")
# Out:
# file save

# %%
with open("fake_review_model.pkl", "rb") as f:
    loaded_model = pickle.load(f)
with open("tfidf_vectorizer.pkl", "rb") as f:
    loaded_tfidf = pickle.load(f)

def predict_review(text):
    text = clean_text(text)
    vec = loaded_tfidf.transform([text])
    return loaded_model.predict(vec)[0]

print("Example:", predict_review("This product is amazing, I love it!"))
# Out:
# Example: OR
